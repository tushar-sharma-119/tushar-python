# %% [markdown]
# <a href="https://colab.research.google.com/github/tushar-sharma-119/tushar-python/blob/main/python_yt_day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# commments and variables

# %%
# it is used for single line comments
"""sdkjfadpfjf
ad;fkjadfjadfj
aldk;alfka;lfk""" is used for multiple line comments

# %% [markdown]
# variables

# %%
# in python variables used as storage (container)
a = 12 # a is the storage , we can assign storage
print(a)
# Out:
# 12

# %%
# strings
# string slicing
a = "jaipur moorti palace"
print(type(a))
print(a[3])#string indexing
print(a[0:9])
print(a[:])
# Out:
# <class 'str'>
# p
# jaipur mo
# jaipur moorti palace

# %%
#string
#type conversions
a=12
a=str(a)
print(type(a))
# Out:
# <class 'str'>

# %%
a="12"
a=int(a)
print(type(a))
# Out:
# <class 'int'>

# %%
a= "0""223"
print(bool(a))
# Out:
# True

# %%
# there are 7 falsy values = false,0,0.0,"",[],(),{}
a = ""
print(bool(a))
# Out:
# False

# %%
# implicit and explicit

# %%
# input and output


name = "akash"
age = "23"
print(name,age)
# Out:
# akash 23

# %%
name = "akash"
age = "23"
print("my name is",name,"and my age is",age)
# Out:
# my name is akash and my age is 23

# %%
age = bool (input("what is your age"))
print(age)
print(type(age))
# Out:
# what is your age22
# True
# <class 'bool'>

# %%
a = input("enter your number = ")
print(a)
# Out:
# enter your number = 222
# 222

# %%
a = input("enter your age")
print(a)
print(type(a))
# Out:
# enter your age34
# 34
# <class 'str'>

# %% [markdown]
# arithemetic operators

# %%
 a = 12
 b = 20


 print(a+b)
 print(a-b)
 print(a*b)
 print(a/b)
 print(a//b)
 print(a%b)
 print(a**b)
# Out:
# 32
# -8
# 240
# 0.6
# 0
# 12
# 3833759992447475122176
