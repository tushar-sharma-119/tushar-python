# %% [markdown]
# <a href="https://colab.research.google.com/github/tushar-sharma-119/tushar-python/blob/main/day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#list method append
l =[10,20,30,]
l.append(40)
l
# Out:
# [10, 20, 30, 40]

# %%
# list method insert
l =[10,20,30,]
l.insert(1,15)
l
# Out:
# [10, 15, 20, 30]

# %%
#length
l =[10,20,30,]
len(l)
# Out:
# 3

# %%
#list element access
l =[10,20,30,]
l[0]
# Out:
# 10

# %%
# for
for a in range(5):
 print(a)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
l=[10,20,30]
len(l)
# Out:
# 3

# %%
for i in range(3):
  print(i)
# Out:
# 0
# 1
# 2

# %%
for i in range(len(l)):
  print(i)
# Out:
# 0
# 1
# 2

# %%
for i in range(len(l)):
  print(l(i))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_628/426739542.py in <cell line: 0>()
#       1 for i in range(len(l)):
# ----> 2   print(l(i))
#
# TypeError: 'list' object is not callable

# %%
d = {"users":['nik','raj']}
for i in range(len(l)):
  print(i)
# Out:
# 0
# 1

# %%
for i in range(2):
  print(d)
# Out:
# {'users': ['nik', 'raj']}
# {'users': ['nik', 'raj']}

# %%
for i in range(2):
  print(d{['users']:'1'))
# Out:
#   File "/tmp/ipykernel_628/2570602967.py", line 2
#     print(d{['users']:'1'))
#                          ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '{'

# %%
d = {'name': 'raj','age':20,'roll no':25}
d.keys()
# Out:
# dict_keys(['name', 'age', 'roll no'])

# %%
for i in range(3):
  print(i)
# Out:
# 0
# 1
# 2

# %%
for i in range(3):
  print(d.keys())
# Out:
# dict_keys(['name', 'age', 'roll no'])
# dict_keys(['name', 'age', 'roll no'])
# dict_keys(['name', 'age', 'roll no'])

# %%
for i in d.keys():
  print (i)
# Out:
# name
# age
# roll no

# %%
for i in d.keys():
  print (d[i])
# Out:
# raj
# 20
# 25

# %%
def hello():
  print("hello function")
hello()
# Out:
# hello function

# %%
def name(a):
  print(a)
name("nik")
# Out:
# nik

# %%
def name(a,b):
   print("a.b")
   name("tushar
