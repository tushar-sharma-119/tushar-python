# %% [markdown]
# <a href="https://colab.research.google.com/github/tushar-sharma-119/tushar-python/blob/main/day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("day 3")
# Out:
# day 3

# %%
#if
num1 = 10
if num1 > 2:
  print("num1 =",num1)
  print(type(num1))
  print(id(num1))
print("if end")
# Out:
# num1 = 10
# <class 'int'>
# 11645640
# if end

# %%
# if else
num1=20
num2=10
if num1<= num2:
  print("if part run")
else:
  print("else part run")
# Out:
# else part run

# %%
# if elif else
num1=int(input("enter the number:"))
num2=20
num3=30
if num1 > num2:
  print("if part run")
elif num1 > num3:
  print("elif part run")
else:
  print("else part run")
# Out:
# enter the number:77
# if part run

# %%
marks=int(input("enter marks="))
if marks>=95:
  print('a')
elif marks>=90:
  print('b')
elif marks>= 75:
  print('c')
elif marks>= 60:
  print('d')
else :
  print('fail')
# Out:
# enter marks=55
# fail

# %%
#list
A=(10,20,30)
print('A(o)')
print('A(1)')
print('A(2)')
#negative indexing
# Out:
# A(o)
# A(1)
# A(2)
# a(-1)

# %%
#dict
d = {"name":"tushar"}
print(d)
print(d.get('name'))

#example
d = {"name":"tushar from jaipur","city":"jaipur"}
print(d)
print(d['name'],['city'])
# Out:
# {'name': 'tushar'}
# tushar
# {'name': 'tushar from jaipur', 'city': 'jaipur'}
# tushar from jaipur ['city']

# %%
d={"age": 20,"name":"tushar"}
print(d['age'])
print(d['name'])
# Out:
# 20
# tushar

# %%
d={"users":["nik","raj"]}
print(d)
print(d['users'][0])
print(d['users'][1])
# Out:
# {'users': ['nik', 'raj']}
# nik
# raj

# %%
d={"users":[{"name":"hello","name":"world"}]}
print(d['users'][0]['name'])
# Out:
# world
