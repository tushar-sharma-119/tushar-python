# %% [markdown]
# <a href="https://colab.research.google.com/github/tushar-sharma-119/tushar-python/blob/main/functions_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # functions

# %%
def hello():
  print("i am tushar")

hello()
# Out:
# i am tushar

# %%
def value(a,b):
  print(f"the sum of value = {a+b}")

value(22,22)
# Out:
# the sum of value = 44
# the sum of value = 40

# %%
def value(a,b):
  print(f"the sum of value = {a+b}")

value(20,20)
value (13,23)
# Out:
# the sum of value = 40
# the sum of value = 36

# %%
def hello(name,age):
  print(f"my name is {name} and my age is {age}")

hello("tushar",22)
# Out:
# my name is tushar and my age is 22

# %%
def hello(name,age):
  print(f"my name is {name} and my age is {age}")

hello(age = 22,name = "tushar")# keyword argument
# Out:
# my name is tushar and my age is 22

# %%
def value(a,b=45):
  print(f"the sum of value = {a+b}")

value(5)
# Out:
# the sum of value = 50

# %%
def value(a,b=45):# put a default parameter
  print(f"the sum of value = {a+b}")

value(5,15) # default argument
# Out:
# the sum of value = 20

# %%
def name(a):
 rev=""

 for i in range(len(a)-1,-1,-1):
  rev = rev + a[i]


 if rev == a:
    print("pallindrome")
 else:
    print("not pallinedrome")


name("naman")
name("tushar")
# Out:
# pallindrome
# not pallinedrome

# %%
def hello():
  return "hello how are you"

print(hello())
# Out:
# hello how are you
