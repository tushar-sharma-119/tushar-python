# %% [markdown]
# <a href="https://colab.research.google.com/github/tushar-sharma-119/tushar-python/blob/main/day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("day 3")
# Out:
# day 3

# %%
#if
num1 = 10
if num1 > 2:
  print("num1 =",num1)
  print(type(num1))
  print(id(num1))
print("if end")
# Out:
# num1 = 10
# <class 'int'>
# 11645640
# if end

# %%
# if else
num1=20
num2=10
if num1<= num2:
  print("if part run")
else:
  print("else part run")
# Out:
# else part run

# %%
# if elif else
num1=int(input("enter the number:"))
num2=20
num3=30
if num1 > num2:
  print("if part run")
elif num1 > num3:
  print("elif part run")
else:
  print("else part run")
